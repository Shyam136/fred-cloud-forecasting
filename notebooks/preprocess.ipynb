# %% [markdown]
# # Preprocessing Enhancements
# This notebook applies log-diff and percentage change transformations to target columns and normalizes regressors.

# %% [markdown]
# ## Rationale
# - Log-diff stabilizes variance and makes trends more stationary.
# - Percentage change captures relative changes over time.
# - Normalization ensures regressors are on comparable scales for modeling.

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
# Load data and apply transformations as per pipeline
